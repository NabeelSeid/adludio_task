# %% [markdown]
# ### Import Relevant packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Read the dataset

# %%
df = pd.read_csv('./dataset.csv')

# %% [markdown]
# ### Compute click through rate

# %%
df['click_through_rates'] = df['click-through-event'] / df['impression']

# %% [markdown]
# ### Replace catagorical values with dummy variabels
#
# Since region and season are catagorical values and have more than two values we will replace them with dummy variables to compute their correlation with click_through_rates

# %%
df_dummies_region = pd.get_dummies(df['region'])
df_dummies_season = pd.get_dummies(df['season'])

del df_dummies_region[df_dummies_region.columns[-1]]
del df_dummies_season[df_dummies_season.columns[-1]]

df_new = df.copy()
del df_new['region'] 
del df_new['first_key'] 
del df_new['version'] 
del df_new['season'] 
del df_new['vertical'] 
del df_new['click-through-event']
del df_new['first_dropped'] 
del df_new['impression']

df_region = pd.concat([df_new, df_dummies_region], axis=1)
df_season = pd.concat([df_new, df_dummies_season], axis=1)

# %% [markdown]
# ### Correlation between region and click through rate

# %%
df_region.corr()
# Out:
#                      click_through_rates    Africa  Americas      Asia  \
# click_through_rates             1.000000 -0.020965  0.105448 -0.037462
# Africa                         -0.020965  1.000000 -0.062936 -0.077779
# Americas                        0.105448 -0.062936  1.000000 -0.175069
# Asia                           -0.037462 -0.077779 -0.175069  1.000000
# Europe                         -0.141266 -0.083496 -0.187938 -0.232260
# Oceania                         0.024231 -0.005850 -0.013168 -0.016273
#
#                        Europe   Oceania
# click_through_rates -0.141266  0.024231
# Africa              -0.083496 -0.005850
# Americas            -0.187938 -0.013168
# Asia                -0.232260 -0.016273
# Europe               1.000000 -0.017469
# Oceania             -0.017469  1.000000

# %% [markdown]
# ### Correlation graph between region and click through rate

# %%
df_region.corr().style.background_gradient(cmap='PRGn')
# Out:
# <style  type="text/css" >
#     #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col1 {
#             background-color:  #5e176a;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col2 {
#             background-color:  #ac89bc;
#             color:  #000000;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col3 {
#             background-color:  #8a529a;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col4 {
#             background-color:  #661e73;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col5 {
#             background-color:  #551061;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col0 {
#             background-color:  #772b84;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col2 {
#             background-color:  #772b84;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col3 {
#             background-color:  #7f3c8d;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col4 {
#             background-color:  #7c368a;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col5 {
#             background-color:  #44034f;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col0 {
#             background-color:  #9f78b1;
#             color:  #000000;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col1 {
#             background-color:  #480754;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col3 {
#             background-color:  #571263;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col4 {
#             background-color:  #530f5f;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col5 {
#             background-color:  #42024d;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row3_col0 {
#             background-color:  #71267e;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row3_col1 {
#             background-color:  #42024d;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row3_col2 {
#             background-color:  #44034f;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row3_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row3_col4 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row3_col5 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row4_col0 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row4_col1 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row4_col2 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row4_col3 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row4_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row4_col5 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row5_col0 {
#             background-color:  #864a95;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row5_col1 {
#             background-color:  #661e73;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row5_col2 {
#             background-color:  #864a95;
#             color:  #f1f1f1;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row5_col3 {
#             background-color:  #8f5da0;
#             color:  #000000;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row5_col4 {
#             background-color:  #8f5da0;
#             color:  #000000;
#         }    #T_5523dc4e_41f1_11eb_aa12_235151ec83c9row5_col5 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >click_through_rates</th>        <th class="col_heading level0 col1" >Africa</th>        <th class="col_heading level0 col2" >Americas</th>        <th class="col_heading level0 col3" >Asia</th>        <th class="col_heading level0 col4" >Europe</th>        <th class="col_heading level0 col5" >Oceania</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9level0_row0" class="row_heading level0 row0" >click_through_rates</th>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col1" class="data row0 col1" >-0.020965</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col2" class="data row0 col2" >0.105448</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col3" class="data row0 col3" >-0.037462</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col4" class="data row0 col4" >-0.141266</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row0_col5" class="data row0 col5" >0.024231</td>
#             </tr>
#             <tr>
#                         <th id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9level0_row1" class="row_heading level0 row1" >Africa</th>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col0" class="data row1 col0" >-0.020965</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col2" class="data row1 col2" >-0.062936</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col3" class="data row1 col3" >-0.077779</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col4" class="data row1 col4" >-0.083496</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row1_col5" class="data row1 col5" >-0.005850</td>
#             </tr>
#             <tr>
#                         <th id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9level0_row2" class="row_heading level0 row2" >Americas</th>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col0" class="data row2 col0" >0.105448</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col1" class="data row2 col1" >-0.062936</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col3" class="data row2 col3" >-0.175069</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col4" class="data row2 col4" >-0.187938</td>
#                         <td id="T_5523dc4e_41f1_11eb_aa12_235151ec83c9row2_col5" class="data row2 col5" >-0.013168</td>
#             </tr>
#             <tr>

# %% [markdown]
# ### Correlation between season and click through rate

# %%
df_season.corr()
# Out:
#                      click_through_rates    Autumn     Hiver    Spring  \
# click_through_rates             1.000000 -0.045820 -0.073163  0.016066
# Autumn                         -0.045820  1.000000 -0.138082 -0.236966
# Hiver                          -0.073163 -0.138082  1.000000 -0.147519
# Spring                          0.016066 -0.236966 -0.147519  1.000000
# Summer                          0.068927 -0.378739 -0.235778 -0.404622
#
#                        Summer
# click_through_rates  0.068927
# Autumn              -0.378739
# Hiver               -0.235778
# Spring              -0.404622
# Summer               1.000000

# %% [markdown]
# ### Correlation graph between season and click through rate

# %%
df_season.corr().style.background_gradient(cmap='PRGn')
# Out:
# <style  type="text/css" >
#     #T_61630778_41f1_11eb_aa12_235151ec83c9row0_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row0_col1 {
#             background-color:  #a985b9;
#             color:  #000000;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row0_col2 {
#             background-color:  #803f8f;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row0_col3 {
#             background-color:  #c1a4ce;
#             color:  #000000;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row0_col4 {
#             background-color:  #d0b7d8;
#             color:  #000000;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row1_col0 {
#             background-color:  #4d0a58;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row1_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row1_col2 {
#             background-color:  #6a2177;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row1_col3 {
#             background-color:  #7c368a;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row1_col4 {
#             background-color:  #480754;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row2_col0 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row2_col1 {
#             background-color:  #8f5da0;
#             color:  #000000;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row2_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row2_col3 {
#             background-color:  #9262a3;
#             color:  #000000;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row2_col4 {
#             background-color:  #7c368a;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row3_col0 {
#             background-color:  #6c2379;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row3_col1 {
#             background-color:  #772b84;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row3_col2 {
#             background-color:  #661e73;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row3_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row3_col4 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row4_col0 {
#             background-color:  #803f8f;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row4_col1 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row4_col2 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row4_col3 {
#             background-color:  #40004b;
#             color:  #f1f1f1;
#         }    #T_61630778_41f1_11eb_aa12_235151ec83c9row4_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_61630778_41f1_11eb_aa12_235151ec83c9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >click_through_rates</th>        <th class="col_heading level0 col1" >Autumn</th>        <th class="col_heading level0 col2" >Hiver</th>        <th class="col_heading level0 col3" >Spring</th>        <th class="col_heading level0 col4" >Summer</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61630778_41f1_11eb_aa12_235151ec83c9level0_row0" class="row_heading level0 row0" >click_through_rates</th>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row0_col1" class="data row0 col1" >-0.045820</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row0_col2" class="data row0 col2" >-0.073163</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row0_col3" class="data row0 col3" >0.016066</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row0_col4" class="data row0 col4" >0.068927</td>
#             </tr>
#             <tr>
#                         <th id="T_61630778_41f1_11eb_aa12_235151ec83c9level0_row1" class="row_heading level0 row1" >Autumn</th>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row1_col0" class="data row1 col0" >-0.045820</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row1_col2" class="data row1 col2" >-0.138082</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row1_col3" class="data row1 col3" >-0.236966</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row1_col4" class="data row1 col4" >-0.378739</td>
#             </tr>
#             <tr>
#                         <th id="T_61630778_41f1_11eb_aa12_235151ec83c9level0_row2" class="row_heading level0 row2" >Hiver</th>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row2_col0" class="data row2 col0" >-0.073163</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row2_col1" class="data row2 col1" >-0.138082</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row2_col3" class="data row2 col3" >-0.147519</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row2_col4" class="data row2 col4" >-0.235778</td>
#             </tr>
#             <tr>
#                         <th id="T_61630778_41f1_11eb_aa12_235151ec83c9level0_row3" class="row_heading level0 row3" >Spring</th>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row3_col0" class="data row3 col0" >0.016066</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row3_col1" class="data row3 col1" >-0.236966</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row3_col2" class="data row3 col2" >-0.147519</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row3_col4" class="data row3 col4" >-0.404622</td>
#             </tr>
#             <tr>
#                         <th id="T_61630778_41f1_11eb_aa12_235151ec83c9level0_row4" class="row_heading level0 row4" >Summer</th>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row4_col0" class="data row4 col0" >0.068927</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row4_col1" class="data row4 col1" >-0.378739</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row4_col2" class="data row4 col2" >-0.235778</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row4_col3" class="data row4 col3" >-0.404622</td>
#                         <td id="T_61630778_41f1_11eb_aa12_235151ec83c9row4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>
